# %% [markdown]
# #1. File Upload

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-9b10515d-43ef-4386-abde-f4e9d91a2056" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b10515d-43ef-4386-abde-f4e9d91a2056">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1.jpg

# %% [markdown]
# #2. Load File

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
print("OpenCV version: ", cv2.__version__)
# Out:
# OpenCV version:  4.1.2

# %%
# !ls -al
# Out:
# total 96
# drwxr-xr-x 1 root root  4096 Mar  8 02:00 .
# drwxr-xr-x 1 root root  4096 Mar  8 01:57 ..
# -rw-r--r-- 1 root root 77963 Mar  8 02:00 car1.jpg
# drwxr-xr-x 4 root root  4096 Mar  1 14:35 .config
# drwxr-xr-x 1 root root  4096 Mar  1 14:35 sample_data

# %%
img = cv2.imread('car1.jpg')

# %%
cv2_imshow(img)

print("width: {} pixels".format(img.shape[1]))
print("heigh: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F94C2655510>
# width: 1280 pixels
# heigh: 720 pixels
# channels: 3

# %%
X = 153 #@param {type:"slider", min:0, max:1280, step:1}
Y = 354 #@param {type:"slider", min:0, max:720, step:1}
SIZE = 100 #@param {type:"slider", min:0, max:200, step:1}

# %%
(b,g,r) = img[X, Y]
print("Pixel at ({}, {}) - Red: {}, Green: {}, Blue: {}".format(X, Y, r, g, b))
# Out:
# Pixel at (153, 354) - Red: 157, Green: 212, Blue: 242

# %%
# Crop cordination = image[y: y+h, x:x+w]
croped = img[Y:Y+SIZE, X:X+SIZE]
cv2_imshow(croped)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F94BDEC4BD0>

# %%
img[Y:Y+SIZE, X:X+SIZE] = (0, 0, 255)

# %%
cv2.rectangle(img, (X+SIZE*2, Y), (X+SIZE*3, Y+SIZE), (0,255, 0), 5)

# %%
radius = int(SIZE/2)
cv2.circle(img, (X+SIZE*4, Y+radius), radius, (255,255, 0), -1)

# %%
cv2.line(img, (X+SIZE*5, Y), (X+SIZE*6, Y+SIZE), (0, 255, 255), 5)

# %%
cv2.putText(img, 'creApple', (X+SIZE*7, Y+SIZE), cv2.FONT_HERSHEY_COMPLEX, 1, (255, 0, 0))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F94BDECC590>

# %%
cv2.imwrite('car-copy.jpg', img)
# Out:
# True

# %%
# !ls -al
# Out:
# total 276
# drwxr-xr-x 1 root root   4096 Mar  8 02:24 .
# drwxr-xr-x 1 root root   4096 Mar  8 01:57 ..
# -rw-r--r-- 1 root root  77963 Mar  8 02:00 car1.jpg
# -rw-r--r-- 1 root root 184188 Mar  8 02:24 car-copy.jpg
# drwxr-xr-x 4 root root   4096 Mar  1 14:35 .config
# drwxr-xr-x 1 root root   4096 Mar  1 14:35 sample_data

# %%
def download(path):
    try:
        from google.colab import files
        files.download(path)
    except ImportError:
        import os
        print('Error download: ', os.path.join(os, getcwd(), path))

# %%
download('car-copy.jpg')
