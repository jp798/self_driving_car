# %% [markdown]
# 1. File Upload

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-dfa5e7f7-70b7-4679-847c-7ad6a863b6cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfa5e7f7-70b7-4679-847c-7ad6a863b6cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1.jpg

# %% [markdown]
# 2. Import Modules

# %%
import cv2

# %%
import numpy as np

# %%
print("OpenCV version: ", cv2.__version__)
# Out:
# OpenCV version:  4.1.2

# %% [markdown]
# 3. Read image
#
# *   cv2.imread()
# *   cv2.imshow() => Not available at Colab

# %%
# !ls -al
# Out:
# total 96
# drwxr-xr-x 1 root root  4096 Mar  7 23:53 .
# drwxr-xr-x 1 root root  4096 Mar  7 23:49 ..
# -rw-r--r-- 1 root root 77963 Mar  7 23:53 car1.jpg
# drwxr-xr-x 4 root root  4096 Mar  1 14:35 .config
# drwxr-xr-x 1 root root  4096 Mar  1 14:35 sample_data

# %%
img = cv2.imread('car1.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('My Car', img)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-8-6274edc67c6c> in <module>()
# ----> 1 cv2.imshow('My Car', img)
#
# /usr/local/lib/python3.7/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# 4. 3 ways to show image

# %%
# Solution 1, Matplotlib
import matplotlib.pyplot as plt

rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
plt.imshow(rgb_img)
plt.show()
plt.imshow(gray)
plt.show()

# %%
# Solution 2, Colab
from google.colab.patches import cv2_imshow
cv2_imshow(img)

print("width: {} pixels".format(img.shape[1]))
print("height: {} pixels".format(img.shape[0]))
print("channels: {}".format(img.shape[2]))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F0171D08310>
# width: 1280 pixels
# height: 720 pixels
# channels: 3

# %%
# Solution 3, PIL
import PIL.Image as Image

Image.fromarray(rgb_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F0171CB5450>
